# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('data/color space.png')
plt.imshow(img)
plt.title("Original Image")
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(imgrgb)
